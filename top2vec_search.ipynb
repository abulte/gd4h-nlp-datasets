# %% [markdown]
# # Top2vec - search
#
# Explore a top2vec model based on data.gouv.fr's catalog.
#
# ## Model training instructions
#
# **warning** `learn_top2vec.py` needs a python 3.10 env to run (some libraries not compatible with python > 3.10 ATM).
#
# You need to install [qsv](https://qsv.dathere.com) in order to preprocess the CSV catalog file.
#
# ```shell
# pip install top2vec[sentence_transformers]
# # download the latest catalog
# make download
# # create a cleaned version of the catalog
# make filter
# # train the model
# python learn_top2vec.py train-model
# ```

# %%
from top2vec import Top2Vec

# %%
embedding_model = "distiluse-base-multilingual-cased"
model_file = f"top2vec_{embedding_model}.bin"
model = Top2Vec.load(model_file)

# %%
model.get_num_topics()
# Out:
# 541

# %% [markdown]
# ## Use keywords.yml for search_topics
#
# Tokenize keywords.yml for every theme and apply search_topics for keywords that are in the vector space.
#
# Get a list of interesting topics for every theme, filter them by common topics (too common, not precise enough) and manual pruning. Use `score = topic_score_in_query * doc_score_in_topic` to normalize scores across topics for a given theme. Keep the common topics apart because they might be interesting overall, even if they're not specific to a theme.
#
# Export a list of documents for every prefered topic(s) for every theme.

# %%
from top2vec.Top2Vec import default_tokenizer

# %%
from utils import load_raw_keywords, load_kw_file

# %%
tokenized_tags = {}
for theme, tags in load_kw_file().items():
    tokenized_tags[theme] = [default_tokenizer(t) for t in tags]
tokenized_tags
# Out:
# {'Gestion des eaux': [['eau'], ['stress', 'hydrique'], ['trame', 'bleue']],
#  'Qualité des sols': [['sol'], ['poussiere'], ['sediment']],
#  'Aménagement et occupation du sol': [['sol'],
#   ['occupation'],
#   ['usage'],
#   ['amiante']],
#  'Champs électromagnétiques': [['rayonnements', 'ionisants'],
#   ['rayonnements', 'non', 'ionisants'],
#   ['rayonnements', 'optiques'],
#   ['nanoparticules', 'de', 'carbone'],
#   ['champs']],
#  "Qualité de l'air": [['air'], ['monoxyde', 'de', 'carbone']],
#  'Environnement sonore': [['bruit'],
#   ['nuisance', 'sonore'],
#   ['ambiance', 'thermique'],
#   ['vibration']],
#  'Luminosité': [['eclairage', 'public']],
#  'Température': [['canicule'],
#   ['ilot', 'de', 'chaleur'],
#   ['ilot', 'de', 'fraicheur'],
#   ['temperature']],
#  'Risques alimentaires': [['aliment'], ['conservateur']],
#  'Biodiversité': [['faune'],
#   ['flore'],
#   ['vegetal'],
#   ['vegetaux'],
#   ['insecte'],
#   ['reservoir', 'biologique'],
#   ['bacterie'],
#   ['champignon', 'microscopique'],
#   ['trame', 'verte'],
#   ['vegetalisation'],
#   ['vegetation'],
#   ['parc'],
#   ['nature', 'en', 'ville'],
#   ['espaces', 'verts'],
#   ['zoonose']],
#  'Autre': [['virus'],
#   ['parasite'],
#   ['prion'],
#   ['pollen'],
#   ['toxine'],
#   ['metaux', 'lourds'],
#   ['pesticides'],
#   ['produits', 'phytosanitaires'],
#   ['biocides'],
#   ['polluant'],
#   ['hydrocarbure'],
#   ['perturbateurs', 'endocriniens'],
#   ['pcb'],
#   ['dioxine'],
#   ['acrylamide'],
#   ['plomb'],
#   ['arsenic'],
#   ['chlordecone'],
#   ['pfas']]}

# %%
def top_topics_for_theme(theme, num_topics=5):
    # flatten tokenized tags - maybe keep expressions together (eg "trame bleue" instead of "trame", "bleue")
    tags = [t for sublist in tokenized_tags[theme] for t in sublist if t in model.vocab]
    if not tags:
        print(f"Not tag in keyword space for {theme}")
        return []
    topic_words, word_scores, topic_scores, topic_nums = model.search_topics(
        keywords=tags, num_topics=num_topics
    )
    return topic_nums, topic_scores

# %%
topics = {theme: top_topics_for_theme(theme) for theme in tokenized_tags.keys()}
topics
# Out:
# Not tag in keyword space for Risques alimentaires
# {'Gestion des eaux': (array([ 20, 316,  89, 163, 426]),
#   array([0.54194508, 0.4177227 , 0.20196472, 0.19771077, 0.13278842])),
#  'Qualité des sols': (array([ 20, 316,  84,  89, 452]),
#   array([0.49099797, 0.40614742, 0.21147323, 0.18543416, 0.13105288])),
#  'Aménagement et occupation du sol': (array([316,  20,  89,  84, 126]),
#   array([0.56150682, 0.51652438, 0.22628652, 0.20274832, 0.19166021])),
#  'Champs électromagnétiques': (array([ 20, 316,  89,  84, 452]),
#   array([0.5562695 , 0.50407138, 0.19869777, 0.17012875, 0.14657172])),
#  "Qualité de l'air": (array([ 20, 316,  89, 442, 326]),
#   array([0.56656545, 0.50421575, 0.24073483, 0.17666679, 0.15243493])),
#  'Environnement sonore': (array([ 20, 316,  89, 334, 322]),
#   array([0.51910887, 0.44274878, 0.24457613, 0.15587113, 0.15249304])),
#  'Luminosité': (array([316,  20, 349, 108,  89]),
#   array([0.53738952, 0.48034521, 0.37904333, 0.33550778, 0.30238005])),
#  'Température': (array([ 20, 316,  89,  84, 240]),
#   array([0.60876428, 0.50131805, 0.24515739, 0.13762054, 0.12865796])),
#  'Risques alimentaires': [],
#  'Biodiversité': (array([ 20, 316,  89,  84, 452]),
#   array([0.59790613, 0.51994501, 0.24080454, 0.20305049, 0.16923843])),
#  'Autre': (array([ 20, 316,  89,  84, 326]),
#   array([0.63783754, 0.58459106, 0.35913519, 0.20738411, 0.1907521 ]))}

# %%
def get_topic_words(topic_num):
    return model.topic_words[topic_num]
    
# compute list of topics present in all the themes
topics_lists = [t[0] for t in topics.values() if t]
topics_intersection = set(topics_lists[0])
for array in topics_lists[1:]:
    if len(array):
        topics_intersection &= set(array)
topics_intersection = list(topics_intersection)

for ti in topics_intersection:
    print(ti, get_topic_words(ti))
# Out:
# 89 ['recharges' 'rechargeables' 'recharge' 'surcharge' 'paysdelaloire'
#  'telecharge' 'telecharger' 'telechargement' 'uploads' 'chargee'
#  'remboursement' 'charges' 'recalcules' 'telechargees' 'charge'
#  'redecoupage' 'aufilduboamp' 'defibrillateurs' 'reccordon'
#  'telechargeables' 'relance' 'reprenant' 'recuperees' 'reperage'
#  'restitution' 'ecoulements' 'recuperer' 'repondre' 'renouvelables'
#  'remunerations' 'recouvrement' 'reponses' 'telechargeable' 'livraisons'
#  'indemnites' 'reduite' 'reutilisation' 'remuneration' 'reparties'
#  'recues' 'reperer' 'reclassement' 'auvergne' 'livraison' 'ecoulement'
#  'recale' 'bdparcellaire' 'repertoriees' 'rattachement' 'repondant']
# 20 ['cadastrale' 'aufilduboamp' 'cadastrales' 'paysdelaloire' 'cadastral'
#  'dicopub' 'defavorisees' 'trottinettes' 'decibels' 'decoupees' 'rasters'
#  'allocataires' 'pluenligne' 'municipaux' 'nappes' 'auvergne' 'cadastraux'
#  'geograndest' 'decouverte' 'dalles' 'idarticle' 'navettes' 'matieres'
#  'decoupages' 'epargne' 'relevees' 'baccalaureat' 'ruissellement'
#  'demarches' 'fonciere' 'visent' 'allocataire' 'enquetes' 'canevas'
#  'millesimes' 'cumulees' 'foncier' 'pornic' 'raster' 'sismicite'
#  'menagers' 'menages' 'cavites' 'cotes' 'parcelles' 'amortissements'
#  'estuaires' 'emetteurs' 'cotieres' 'rattachement']
# 316 ['entreprises' 'filiales' 'entreprise' 'entrepreneurs' 'agences'
#  'landesamt' 'agence' 'societes' 'carrieres' 'paysdelaloire' 'agenceore'
#  'agen' 'commercants' 'affaires' 'prestataires' 'emetteurs' 'instaure'
#  'livraisons' 'etablies' 'fournitures' 'detenues' 'deploiement'
#  'renseignes' 'crowdsourcing' 'municipaux' 'caducite' 'instituees'
#  'delegataires' 'covoiturage' 'entites' 'commerciaux' 'patrimoniale'
#  'allocataires' 'fondateur' 'institues' 'coexploitants' 'exploitants'
#  'societe' 'elaborees' 'etudiees' 'millesimes' 'instituant'
#  'organisations' 'etablissements' 'empruntes' 'departementales'
#  'communaux' 'etablis' 'renseignees' 'denominateur']

# %% [markdown]
# **Warning: some topics have been manually excluded below. Their ids might change if the model is re-trained.**

# %%
excluded_topics = [
    *topics_intersection,
    # uninteresting topic (description about description)
    #182,
    # uninteresting topic (manual review GD4H)
    #373,
]

best_topics_for_themes = {}

for theme, theme_topics_with_score in topics.items():
    print(theme)
    if not theme_topics_with_score:
        best_topics_for_themes[theme] = []
        continue
    theme_topics, topic_scores = theme_topics_with_score
    unique_topics = [t for t in zip(theme_topics, topic_scores) if t[0] not in excluded_topics]
    for t in unique_topics:
        print(t[0], get_topic_words(t[0]))
    best_topics_for_themes[theme] = unique_topics

best_topics_for_themes
# Out:
# Gestion des eaux
# 163 ['hydrographiques' 'hydrographique' 'hydrologiques' 'fontaines'
#  'hydrogeologique' 'hydro' 'fontaine' 'irrigation' 'water' 'eau' 'eaux'
#  'hydrographie' 'hydrauliques' 'hydraulique' 'eaufrance' 'inondations'
#  'aquatique' 'aquatiques' 'inondation' 'piscines' 'inondables' 'basin'
#  'reservoirs' 'fluvial' 'reservoir' 'canalisations' 'barrages' 'piscine'
#  'inondable' 'pluviales' 'humide' 'bassins' 'humides' 'fluides' 'bassin'
#  'barrage' 'rivieres' 'submersions' 'submersion' 'ecoulements'
#  'submersibles' 'fleuve' 'riveraines' 'precipitations' 'riviere'
#  'riverains' 'flow' 'toilettes' 'ecoulement' 'baie']
# 426 ['hydrographique' 'hydrographiques' 'eaux' 'hydrologiques' 'water' 'eau'
#  'hydrogeologique' 'irrigation' 'hydro' 'hydrographie' 'aquatique'
#  'fontaines' 'eaufrance' 'aquatiques' 'fontaine' 'inondations'
#  'inondation' 'piscines' 'basin' 'hydrauliques' 'hydraulique' 'reservoir'
#  'inondables' 'reservoirs' 'humide' 'spot' 'bassin' 'barrages' 'bassins'
#  'fluvial' 'piscine' 'points' 'inondable' 'humides' 'barrage' 'pluviales'
#  'urbanisation' 'point' 'canalisations' 'places' 'urbanisees'
#  'localisations' 'municipal' 'local' 'localisees' 'urbanises' 'baie'
#  'localisation' 'accessibles' 'locales']
# Qualité des sols
# 84 ['regionaux' 'regions' 'territoires' 'region' 'territoriaux' 'zones'
#  'regionales' 'regional' 'district' 'regionale' 'territoire' 'localises'
#  'territoriale' 'area' 'zone' 'locales' 'territorial' 'territoriales'
#  'localisees' 'domaines' 'local' 'habitats' 'geolocalises' 'localement'
#  'localisations' 'geolocalisees' 'geolocalise' 'arrondissements' 'locaux'
#  'geolocalisation' 'domaine' 'localisant' 'habitat' 'souterraines'
#  'locale' 'localisee' 'terrain' 'localisation' 'geoportail' 'localise'
#  'secteurs' 'prefectures' 'places' 'souterrains' 'georeferencees'
#  'geolocalisee' 'geomartinique' 'environnants' 'arrondissement' 'terrains']
# 452 ['parking' 'cab' 'stationnement' 'auto' 'car' 'cars' 'parkings' 'voiture'
#  'voitures' 'stationnements' 'automobile' 'autocad' 'vehicule' 'carrefour'
#  'automatique' 'automatiquement' 'cabinet' 'automatiques' 'carthage'
#  'automobiles' 'automatise' 'automatises' 'vehicules' 'automatiser'
#  'bdcarthage' 'cad' 'carres' 'carmen' 'cabinets' 'bdcarto' 'ozcar'
#  'carrefours' 'taxi' 'cayenne' 'cheval' 'casvp' 'cac' 'parc' 'reservoir'
#  'caisse' 'caisses' 'camargue' 'parcs' 'cartouche' 'aufilduboamp'
#  'chapelle' 'covid' 'carto' 'bus' 'ceb']
# Aménagement et occupation du sol
# 84 ['regionaux' 'regions' 'territoires' 'region' 'territoriaux' 'zones'
#  'regionales' 'regional' 'district' 'regionale' 'territoire' 'localises'
#  'territoriale' 'area' 'zone' 'locales' 'territorial' 'territoriales'
#  'localisees' 'domaines' 'local' 'habitats' 'geolocalises' 'localement'
#  'localisations' 'geolocalisees' 'geolocalise' 'arrondissements' 'locaux'
#  'geolocalisation' 'domaine' 'localisant' 'habitat' 'souterraines'
#  'locale' 'localisee' 'terrain' 'localisation' 'geoportail' 'localise'
#  'secteurs' 'prefectures' 'places' 'souterrains' 'georeferencees'
#  'geolocalisee' 'geomartinique' 'environnants' 'arrondissement' 'terrains']
# 126 ['operationnels' 'operationnel' 'operations' 'fonctionnement' 'operation'
#  'operatoire' 'fonctionnelle' 'exploitation' 'fonctionnalites'
#  'travailler' 'exploitees' 'fonctions' 'exploites' 'opere' 'exploitant'
#  'exploitations' 'exploite' 'fonction' 'travail' 'œuvres' 'travaille'
#  'manipulation' 'travaux' 'operateurs' 'exploiter' 'operateur' 'ateliers'
#  'exploitants' 'exploitable' 'oeuvre' 'aufilduboamp' 'paysdelaloire'
#  'erosion' 'cooperation' 'ulterieurement' 'action' 'emplois' 'geobretagne'
#  'traite' 'task' 'traitees' 'traites' 'œuvre' 'actions' 'defavorisees'
#  'defibrillateurs' 'obstacle' 'interoperable' 'missions' 'activites']
# Champs électromagnétiques
# 84 ['regionaux' 'regions' 'territoires' 'region' 'territoriaux' 'zones'
#  'regionales' 'regional' 'district' 'regionale' 'territoire' 'localises'
#  'territoriale' 'area' 'zone' 'locales' 'territorial' 'territoriales'
#  'localisees' 'domaines' 'local' 'habitats' 'geolocalises' 'localement'
#  'localisations' 'geolocalisees' 'geolocalise' 'arrondissements' 'locaux'
#  'geolocalisation' 'domaine' 'localisant' 'habitat' 'souterraines'
#  'locale' 'localisee' 'terrain' 'localisation' 'geoportail' 'localise'
#  'secteurs' 'prefectures' 'places' 'souterrains' 'georeferencees'
#  'geolocalisee' 'geomartinique' 'environnants' 'arrondissement' 'terrains']
# 452 ['parking' 'cab' 'stationnement' 'auto' 'car' 'cars' 'parkings' 'voiture'
#  'voitures' 'stationnements' 'automobile' 'autocad' 'vehicule' 'carrefour'
#  'automatique' 'automatiquement' 'cabinet' 'automatiques' 'carthage'
#  'automobiles' 'automatise' 'automatises' 'vehicules' 'automatiser'
#  'bdcarthage' 'cad' 'carres' 'carmen' 'cabinets' 'bdcarto' 'ozcar'
#  'carrefours' 'taxi' 'cayenne' 'cheval' 'casvp' 'cac' 'parc' 'reservoir'
#  'caisse' 'caisses' 'camargue' 'parcs' 'cartouche' 'aufilduboamp'
#  'chapelle' 'covid' 'carto' 'bus' 'ceb']
# Qualité de l'air
# 442 ['carbone' 'ozone' 'biomethane' 'environnemental' 'carthage' 'ecologique'
#  'ecologie' 'ecologiques' 'cartouche' 'climatique' 'umwelt' 'environment'
#  'roche' 'climatiques' 'gaspar' 'gaz' 'environnement' 'biosphere'
#  'geologique' 'geologiquement' 'geologie' 'geologiques' 'polluant'
#  'pierre' 'geolocalisation' 'atmospheriques' 'polluantes' 'climat'
#  'pollution' 'polluants' 'atmospherique' 'cadmium' 'air' 'geolocalises'
#  'carto' 'equilibre' 'equilibree' 'carmen' 'balances' 'emissions'
#  'geolocalise' 'aire' 'geolocalisees' 'carres' 'pollutions' 'tonnes' 'cac'
#  'geolocalisee' 'ccc' 'geocatalogue']
# 326 ['administrative' 'administratives' 'administratif' 'administratifs'
#  'comptable' 'comptables' 'administration' 'administrations' 'administre'
#  'admin' 'gestion' 'gestionnaire' 'management' 'comptabilisees'
#  'gestionnaires' 'comptabilises' 'comptabilise' 'bdparcellaire'
#  'gouvernance' 'ministerium' 'fonctionnaires' 'comptabilite'
#  'departementaux' 'departemental' 'departementale' 'gouvernement'
#  'departementales' 'comptes' 'departement' 'ministeriels' 'officiels'
#  'blagnac' 'ministeriel' 'officielles' 'getrecordbyid' 'officielle'
#  'fiscalite' 'bdcarthage' 'departements' 'officiel' 'factures' 'fiscal'
#  'paysdelaloire' 'fiscaux' 'republique' 'ministere' 'fiscales' 'fiscale'
#  'ministeres' 'bdcarto']
# Environnement sonore
# 334 ['budget' 'budgetaire' 'budgets' 'budgetaires' 'finances' 'fiscal'
#  'fiscale' 'fiscales' 'depenses' 'economique' 'financement' 'financements'
#  'economiques' 'home' 'financiere' 'economie' 'financier' 'finance'
#  'financieres' 'financiers' 'maison' 'financees' 'prioritaires'
#  'prioritaire' 'financer' 'fiscaux' 'domicile' 'priorites' 'logement'
#  'priorite' 'maisons' 'logements' 'primaires' 'depense' 'preemption'
#  'subvention' 'primitives' 'fiscalite' 'consommations' 'primaire' 'priori'
#  'habitation' 'contribuent' 'factures' 'subventions' 'primitifs'
#  'principales' 'patrimonial' 'consommation' 'cofinance']
# 322 ['nocturne' 'nuit' 'night' 'cartographie' 'cartographiees' 'cartographies'
#  'cartographique' 'cartographiques' 'cartographient' 'cartographier'
#  'maps' 'map' 'soir' 'geographie' 'geographiques' 'geographique'
#  'geomatique' 'evening' 'bruit' 'geolocalisation' 'bruits' 'geostandards'
#  'geostandard' 'geomartinique' 'sonores' 'topographiques' 'topographie'
#  'topographique' 'geoinformations' 'georeferencees' 'sonore' 'bruyante'
#  'kartenn' 'georeferences' 'geologie' 'soiree' 'geologique'
#  'geologiquement' 'geologiques' 'geolocalisees' 'geocodage' 'geolocalisee'
#  'mapinfo' 'geolocalises' 'georisques' 'geolocalise' 'midi' 'geoportail'
#  'audiovisuel' 'cartes']
# Luminosité
# 349 ['public' 'eclairage' 'publics' 'communes' 'publiques' 'municipal'
#  'publique' 'municipales' 'urbanisation' 'photovoltaique' 'transparence'
#  'commune' 'urbanisees' 'urbanises' 'urbaniser' 'municipale' 'urbanisme'
#  'urbaines' 'mairies' 'metropoles' 'urban' 'rayonnement' 'urbaine'
#  'geolocalisation' 'geostandards' 'local' 'metropolitains' 'geostandard'
#  'communale' 'locales' 'district' 'publication' 'metropole' 'residents'
#  'localises' 'communales' 'localisations' 'communal' 'expose' 'urbains'
#  'generale' 'metropolitaine' 'metropolitain' 'spot' 'general'
#  'geolocalisees' 'localisation' 'comtat' 'exposees' 'exposes']
# 108 ['public' 'publics' 'publiques' 'publique' 'publication' 'communes'
#  'liste' 'listes' 'publiees' 'publications' 'openstreetmap' 'listant'
#  'publies' 'publiee' 'publie' 'publier' 'ouvertes' 'municipal'
#  'municipales' 'ouverte' 'publicite' 'commune' 'open' 'ouverts' 'bulletin'
#  'officielles' 'ouvert' 'recensement' 'bulletins' 'communales' 'communale'
#  'ouverture' 'generalites' 'opendatafrance' 'metropolitains' 'ouvertures'
#  'officiels' 'generale' 'communal' 'openig' 'general' 'officiel'
#  'opendata' 'generales' 'mairies' 'metropoles' 'ordinaires' 'officielle'
#  'citoyens' 'populaire']
# Température
# 84 ['regionaux' 'regions' 'territoires' 'region' 'territoriaux' 'zones'
#  'regionales' 'regional' 'district' 'regionale' 'territoire' 'localises'
#  'territoriale' 'area' 'zone' 'locales' 'territorial' 'territoriales'
#  'localisees' 'domaines' 'local' 'habitats' 'geolocalises' 'localement'
#  'localisations' 'geolocalisees' 'geolocalise' 'arrondissements' 'locaux'
#  'geolocalisation' 'domaine' 'localisant' 'habitat' 'souterraines'
#  'locale' 'localisee' 'terrain' 'localisation' 'geoportail' 'localise'
#  'secteurs' 'prefectures' 'places' 'souterrains' 'georeferencees'
#  'geolocalisee' 'geomartinique' 'environnants' 'arrondissement' 'terrains']
# 240 ['decembre' 'novembre' 'janvier' 'fevrier' 'octobre' 'avril' 'mars' 'juin'
#  'dateparution' 'juillet' 'mensuelle' 'dates' 'date' 'mensuels'
#  'mensuelles' 'septembre' 'mensuel' 'mensuellement' 'mois' 'datetexte'
#  'trimestrielle' 'annuel' 'hiver' 'datant' 'annuelle' 'trimestrielles'
#  'annuelles' 'datasud' 'feb' 'annuellement' 'printemps' 'metadata'
#  'datatype' 'nocturne' 'wikidata' 'maj' 'aufilduboamp' 'data' 'night'
#  'saison' 'afd' 'nuit' 'atomdataset' 'calendrier' 'umr' 'avalanches'
#  'neige' 'saisonnieres' 'soiree' 'mes']
# Risques alimentaires
# Biodiversité
# 84 ['regionaux' 'regions' 'territoires' 'region' 'territoriaux' 'zones'
#  'regionales' 'regional' 'district' 'regionale' 'territoire' 'localises'
#  'territoriale' 'area' 'zone' 'locales' 'territorial' 'territoriales'
#  'localisees' 'domaines' 'local' 'habitats' 'geolocalises' 'localement'
#  'localisations' 'geolocalisees' 'geolocalise' 'arrondissements' 'locaux'
#  'geolocalisation' 'domaine' 'localisant' 'habitat' 'souterraines'
#  'locale' 'localisee' 'terrain' 'localisation' 'geoportail' 'localise'
#  'secteurs' 'prefectures' 'places' 'souterrains' 'georeferencees'
#  'geolocalisee' 'geomartinique' 'environnants' 'arrondissement' 'terrains']
# 452 ['parking' 'cab' 'stationnement' 'auto' 'car' 'cars' 'parkings' 'voiture'
#  'voitures' 'stationnements' 'automobile' 'autocad' 'vehicule' 'carrefour'
#  'automatique' 'automatiquement' 'cabinet' 'automatiques' 'carthage'
#  'automobiles' 'automatise' 'automatises' 'vehicules' 'automatiser'
#  'bdcarthage' 'cad' 'carres' 'carmen' 'cabinets' 'bdcarto' 'ozcar'
#  'carrefours' 'taxi' 'cayenne' 'cheval' 'casvp' 'cac' 'parc' 'reservoir'
#  'caisse' 'caisses' 'camargue' 'parcs' 'cartouche' 'aufilduboamp'
#  'chapelle' 'covid' 'carto' 'bus' 'ceb']
# Autre
# 84 ['regionaux' 'regions' 'territoires' 'region' 'territoriaux' 'zones'
#  'regionales' 'regional' 'district' 'regionale' 'territoire' 'localises'
#  'territoriale' 'area' 'zone' 'locales' 'territorial' 'territoriales'
#  'localisees' 'domaines' 'local' 'habitats' 'geolocalises' 'localement'
#  'localisations' 'geolocalisees' 'geolocalise' 'arrondissements' 'locaux'
#  'geolocalisation' 'domaine' 'localisant' 'habitat' 'souterraines'
#  'locale' 'localisee' 'terrain' 'localisation' 'geoportail' 'localise'
#  'secteurs' 'prefectures' 'places' 'souterrains' 'georeferencees'
#  'geolocalisee' 'geomartinique' 'environnants' 'arrondissement' 'terrains']
# 326 ['administrative' 'administratives' 'administratif' 'administratifs'
#  'comptable' 'comptables' 'administration' 'administrations' 'administre'
#  'admin' 'gestion' 'gestionnaire' 'management' 'comptabilisees'
#  'gestionnaires' 'comptabilises' 'comptabilise' 'bdparcellaire'
#  'gouvernance' 'ministerium' 'fonctionnaires' 'comptabilite'
#  'departementaux' 'departemental' 'departementale' 'gouvernement'
#  'departementales' 'comptes' 'departement' 'ministeriels' 'officiels'
#  'blagnac' 'ministeriel' 'officielles' 'getrecordbyid' 'officielle'
#  'fiscalite' 'bdcarthage' 'departements' 'officiel' 'factures' 'fiscal'
#  'paysdelaloire' 'fiscaux' 'republique' 'ministere' 'fiscales' 'fiscale'
#  'ministeres' 'bdcarto']
# {'Gestion des eaux': [(163, 0.1977107676465379), (426, 0.1327884210067234)],
#  'Qualité des sols': [(84, 0.2114732283376602), (452, 0.13105288015020358)],
#  'Aménagement et occupation du sol': [(84, 0.20274832065432397),
#   (126, 0.1916602111371217)],
#  'Champs électromagnétiques': [(84, 0.17012875036887068),
#   (452, 0.14657172183565664)],
#  "Qualité de l'air": [(442, 0.1766667883827392), (326, 0.1524349284951491)],
#  'Environnement sonore': [(334, 0.15587112702559344),
#   (322, 0.15249303640182527)],
#  'Luminosité': [(349, 0.3790433334865524), (108, 0.33550778038614837)],
#  'Température': [(84, 0.1376205353558292), (240, 0.1286579575578883)],
#  'Risques alimentaires': [],
#  'Biodiversité': [(84, 0.20305048795915248), (452, 0.16923843252177817)],
#  'Autre': [(84, 0.20738411187344769), (326, 0.19075210358577177)]}

# %%
import csv
from datetime import datetime
from pathlib import Path
from slugify import slugify

output_path = Path("output") / datetime.now().strftime('%Y%m%d-%H%M%S')
output_path.mkdir(exist_ok=True)

for theme, topics_with_score in best_topics_for_themes.items():
    print(theme)
    theme_docs_with_scores = []
    for topic_num, topic_score in topics_with_score:
        doc_scores, doc_ids = model.search_documents_by_topic(
            topic_num, model.topic_sizes[topic_num], return_documents=False
        )
        # account for topic match score to query * doc match score to topic
        normalized_score = doc_scores * topic_score
        theme_docs_with_scores += zip(doc_ids, normalized_score, [topic_num for _ in doc_ids])
    # sort by normalized score after merge
    theme_docs_with_scores.sort(key=lambda x: x[1], reverse=True)
    # export to CSV
    output_file = f"top2vec-search-output_{slugify(theme)}.csv"
    with (output_path / output_file).open("w") as f:
        writer = csv.DictWriter(f, fieldnames=["slug_or_id", "score", "topic"])
        writer.writeheader()
        writer.writerows([{
            "slug_or_id": item[0],
            "score": item[1],
            "topic": item[2],
        } for item in theme_docs_with_scores])
# Out:
# Gestion des eaux
# Qualité des sols
# Aménagement et occupation du sol
# Champs électromagnétiques
# Qualité de l'air
# Environnement sonore
# Luminosité
# Température
# Risques alimentaires
# Biodiversité
# Autre

# %% [markdown]
# ## Next step
#
# You known have the raw output files in `output/{timestamp}/`. The next step would be to use the following command to map the datasets to existing gd4h organizations and produce filtered outputs in `outputs-filtered`:
#
# ```bash
# python filter_outputs.py map_gd4h
# ```
